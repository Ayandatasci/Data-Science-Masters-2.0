# %%
'''Q1. Explain Class and Object with respect to Object-Oriented 
        Programming. Give a suitable example.'''

'''In object-oriented programming (OOP), a class is a blueprint for 
    creating objects. It defines the data that an object will hold and
    the methods that an object will use to manipulate that data.

An object is an instance of a class. 
It is a real-world entity that has state (data) and behavior (methods).

For example, a Car class might define the following data:

make: The make of the car, such as Toyota/Honda.
model: The model of the car, such as Corolla/Civic.
year: The year the car was made.

The Car class might also define the following methods:

drive(): This method would cause the car to move forward.
brake(): This method would cause the car to stop.
turn(): This method would cause the car to turn.

When a Car object is created, it will have its own unique values for 
the make, model, and year data. It will also have its own methods for 
driving, braking, and turning.'''

class car:
    def __init__(self,make,model,year):
        self.make= make
        self.model= model
        self.year= year

    def drive(self):
        print(f"The {self.make} {self.model} is moving forward")

    def brake(self):
        print(f"The {self.make} {self.model} has stopped")

    def turn(self, direction):
        print(f"The {self.make} {self.model} is turning {direction}")

car1= car("Toyota","Corolla",2020)
car2= car("Honda","Civic",2022)

print(car1.make, car1.model, car1.year)
print(car2.make, car2.model, car2.year)

car1.drive()
car2.brake()
car1.turn("right")

# %%
Q2. Name the four pillars of OOPs.
 
i. Encapsulation
ii. Inheritance
iii. Polymorphism
iv. Abstraction

# %%
'''Q3. Explain why the __init__() function is used. 
        Give a suitable example.'''

#The __init__() function is used in Python to initialize the attributes of an object when it is created, ensuring proper setup and initialization of the object's state.

class employee:
    def __init__(self,company,salary):
        self.company= company
        self.salary= salary
    
    def details(self):
        print(f"The Employee is from {self.company} & salary is ${self.salary}")

em= employee("Google","55k")
em.details()

# %%
'''Q4. Why self is used in OOPs?'''

'''The self parameter is a reference to the current instance of 
the class, and is used to access variables that belong to the class.'''

class Person:
    def __init__(self, name):
        self.name = name

    def greet(self):
        print("Hello, my name is", self.name)

person = Person("Ayan")
person.greet()

# %%
'''Q5. What is inheritance? 
    Give an example for each type of inheritance.'''

'''inheritance is a mechanism where a class can inherit attributes and
 methods from another class. It allows for code reuse, promotes 
 modularity, and facilitates the creation of hierarchical relationships
 between classes.'''

class test:
    def hey(self):
        print("Hi, I am Ayan")
class test1(test):
    pass

tst= test1()
tst.hey()
